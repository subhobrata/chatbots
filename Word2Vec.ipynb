# %% [markdown]
# <a href="https://colab.research.google.com/github/subhobrata/chatbots/blob/master/Word2Vec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# imports needed and set up logging
import gzip
import gensim 
import logging

logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
# Out:
# paramiko missing, opening SSH/SCP/SFTP paths will be disabled.  `pip install paramiko` to suppress

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
data_file="/content/gdrive/My Drive/data/OpinRank/reviews_data.txt.gz"

with gzip.open ('/content/gdrive/My Drive/data/OpinRank/reviews_data.txt.gz', 'rb') as f:
    for i,line in enumerate (f):
        print(line)
        break
# Out:
# b"Oct 12 2009 \tNice trendy hotel location not too bad.\tI stayed in this hotel for one night. As this is a fairly new place some of the taxi drivers did not know where it was and/or did not want to drive there. Once I have eventually arrived at the hotel, I was very pleasantly surprised with the decor of the lobby/ground floor area. It was very stylish and modern. I found the reception's staff geeting me with 'Aloha' a bit out of place, but I guess they are briefed to say that to keep up the coroporate image.As I have a Starwood Preferred Guest member, I was given a small gift upon-check in. It was only a couple of fridge magnets in a gift box, but nevertheless a nice gesture.My room was nice and roomy, there are tea and coffee facilities in each room and you get two complimentary bottles of water plus some toiletries by 'bliss'.The location is not great. It is at the last metro stop and you then need to take a taxi, but if you are not planning on going to see the historic sites in 
# ...

# %%
def read_input(input_file):
    """This method reads the input file which is in gzip format"""
    
    logging.info("reading file {0}...this may take a while".format(input_file))
    
    with gzip.open (input_file, 'rb') as f:
        for i, line in enumerate (f): 

            if (i%10000==0):
                logging.info ("read {0} reviews".format (i))
            # do some pre-processing and return a list of words for each review text
            yield gensim.utils.simple_preprocess (line)

# read the tokenized reviews into a list
# each review item becomes a serries of words
# so this becomes a list of lists
documents = list (read_input (data_file))
logging.info ("Done reading data file")
# Out:
# 2019-04-20 07:18:27,318 : INFO : reading file /content/gdrive/My Drive/data/OpinRank/reviews_data.txt.gz...this may take a while
# 2019-04-20 07:18:27,323 : INFO : read 0 reviews
# 2019-04-20 07:18:29,938 : INFO : read 10000 reviews
# 2019-04-20 07:18:32,074 : INFO : read 20000 reviews
# 2019-04-20 07:18:34,339 : INFO : read 30000 reviews
# 2019-04-20 07:18:36,468 : INFO : read 40000 reviews
# 2019-04-20 07:18:38,839 : INFO : read 50000 reviews
# 2019-04-20 07:18:41,070 : INFO : read 60000 reviews
# 2019-04-20 07:18:42,981 : INFO : read 70000 reviews
# 2019-04-20 07:18:44,689 : INFO : read 80000 reviews
# 2019-04-20 07:18:46,532 : INFO : read 90000 reviews
# 2019-04-20 07:18:48,354 : INFO : read 100000 reviews
# 2019-04-20 07:18:50,985 : INFO : read 110000 reviews
# 2019-04-20 07:18:52,993 : INFO : read 120000 reviews
# 2019-04-20 07:18:55,054 : INFO : read 130000 reviews
# 2019-04-20 07:18:57,269 : INFO : read 140000 reviews
# 2019-04-20 07:18:59,192 : INFO : read 150000 reviews
# ...

# %%
model = gensim.models.Word2Vec (documents, size=150, window=10, min_count=2, workers=10)
model.train(documents,total_examples=len(documents),epochs=10)
# Out:
# 2019-04-20 07:19:54,796 : WARNING : consider setting layer size to a multiple of 4 for greater performance
# 2019-04-20 07:19:54,798 : INFO : collecting all words and their counts
# 2019-04-20 07:19:54,799 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2019-04-20 07:19:55,119 : INFO : PROGRESS: at sentence #10000, processed 1655714 words, keeping 25777 word types
# 2019-04-20 07:19:55,449 : INFO : PROGRESS: at sentence #20000, processed 3317863 words, keeping 35016 word types
# 2019-04-20 07:19:55,839 : INFO : PROGRESS: at sentence #30000, processed 5264072 words, keeping 47518 word types
# 2019-04-20 07:19:56,201 : INFO : PROGRESS: at sentence #40000, processed 7081746 words, keeping 56675 word types
# 2019-04-20 07:19:56,596 : INFO : PROGRESS: at sentence #50000, processed 9089491 words, keeping 63744 word types
# 2019-04-20 07:19:56,983 : INFO : PROGRESS: at sentence #60000, processed 11013723 words, keeping 76781 word types
# ...

# %%
w1 = "dirty"
model.wv.most_similar (positive=w1)
# Out:
# 2019-04-20 07:41:20,153 : INFO : precomputing L2-norms of word weight vectors
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('filthy', 0.8617437481880188),
#  ('unclean', 0.7833159565925598),
#  ('stained', 0.7783558368682861),
#  ('dusty', 0.7598443031311035),
#  ('smelly', 0.7558944225311279),
#  ('grubby', 0.7514758110046387),
#  ('grimy', 0.7397914528846741),
#  ('dingy', 0.7320337295532227),
#  ('disgusting', 0.7157747149467468),
#  ('soiled', 0.7108765840530396)]

# %%
# look up top 6 words similar to 'polite'
w1 = ["polite"]
model.wv.most_similar (positive=w1,topn=6)
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('courteous', 0.9252882599830627),
#  ('friendly', 0.8395301699638367),
#  ('cordial', 0.799207329750061),
#  ('professional', 0.7924385070800781),
#  ('attentive', 0.7798203229904175),
#  ('curteous', 0.7738990187644958)]

# %%
# look up top 6 words similar to 'france'
w1 = ["france"]
model.wv.most_similar (positive=w1,topn=6)
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('canada', 0.6610003113746643),
#  ('spain', 0.6459439992904663),
#  ('germany', 0.6371514201164246),
#  ('hawaii', 0.6175186038017273),
#  ('thailand', 0.616847813129425),
#  ('detroit', 0.6111442446708679)]

# %%
# look up top 6 words similar to 'shocked'
w1 = ["shocked"]
model.wv.most_similar (positive=w1,topn=6)
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('horrified', 0.7923468947410583),
#  ('amazed', 0.7796506285667419),
#  ('dismayed', 0.7626628875732422),
#  ('appalled', 0.7625045776367188),
#  ('stunned', 0.7622439861297607),
#  ('suprised', 0.7323971390724182)]

# %%
# get everything related to stuff on the bed
w1 = ["bed",'sheet','pillow']
w2 = ['couch']
model.wv.most_similar (positive=w1,negative=w2,topn=10)
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('duvet', 0.7195044159889221),
#  ('blanket', 0.7025608420372009),
#  ('mattress', 0.6946322321891785),
#  ('matress', 0.6896300911903381),
#  ('quilt', 0.6673583388328552),
#  ('sheets', 0.6375764608383179),
#  ('pillows', 0.6361213326454163),
#  ('foam', 0.6184872388839722),
#  ('pillowcases', 0.601868748664856),
#  ('comforter', 0.6007131934165955)]

# %%
# similarity between two different words
model.wv.similarity(w1="dirty",w2="smelly")
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# 0.7558944

# %%
# similarity between two identical words
model.wv.similarity(w1="dirty",w2="dirty")
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# 1.0

# %%
# similarity between two unrelated words
model.wv.similarity(w1="dirty",w2="clean")
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# 0.27819902

# %%
# Which one is the odd one out in this list?
model.wv.doesnt_match(["cat","dog","france"])
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/models/keyedvectors.py:895: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   vectors = vstack(self.word_vec(word, use_norm=True) for word in used_words).astype(REAL)
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# 'france'

# %%
# Which one is the odd one out in this list?
model.wv.doesnt_match(["bed","pillow","duvet","shower"])
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/models/keyedvectors.py:895: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   vectors = vstack(self.word_vec(word, use_norm=True) for word in used_words).astype(REAL)
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# 'shower'
